# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
df = pd.DataFrame({
    "name": ["A", "B", "C"],
    "age": [20, 25, 30],
    "marks": [88, 92, 79]
})
print(df)
# Out:
#   name  age  marks
# 0    A   20     88
# 1    B   25     92
# 2    C   30     79

# %%
df = pd.read_csv("data.csv")
df.to_csv("output.csv", index=False)

# %%
print(df["age"])
print(df[["name", "marks"]])
# Out:
# 0    20
# 1    25
# 2    30
# Name: age, dtype: int64
#   name  marks
# 0    A     88
# 1    B     92
# 2    C     79

# %%
print(df.loc[0])  
print(df.loc[:, "marks"])
# Out:
# name      A
# age      20
# marks    88
# Name: 0, dtype: object
# 0    88
# 1    92
# 2    79
# Name: marks, dtype: int64

# %%
print(df.iloc[0:2, 1:3])
# Out:
#    age  marks
# 0   20     88
# 1   25     92

# %%
print(df[df["age"] > 20])
print(df[df["marks"] >= 90])
# Out:
#   name  age  marks
# 1    B   25     92
# 2    C   30     79
#   name  age  marks
# 1    B   25     92

# %%
df["total"] = df["marks"] + 10
print(df)

df = df.drop("total", axis=1)
print(df)
# Out:
#   name  age  marks  total
# 0    A   20     88     98
# 1    B   25     92    102
# 2    C   30     79     89
#   name  age  marks
# 0    A   20     88
# 1    B   25     92
# 2    C   30     79

# %%
df = pd.DataFrame({
    "A": [1, 2, None],
    "B": [4, None, 6]
})

print(df.isna())
print(df.fillna(0))
print(df.dropna())
# Out:
#        A      B
# 0  False  False
# 1  False   True
# 2   True  False
#      A    B
# 0  1.0  4.0
# 1  2.0  0.0
# 2  0.0  6.0
#      A    B
# 0  1.0  4.0

# %%
df = pd.DataFrame({
    "team": ["A","A","B","B"],
    "score": [10,20,30,40]
})

print(df.groupby("team")["score"].mean())
print(df.groupby("team").agg({"score":["sum","mean","max"]}))
# Out:
# team
# A    15.0
# B    35.0
# Name: score, dtype: float64
#      score
#        sum  mean max
# team
# A       30  15.0  20
# B       70  35.0  40

# %%
a = pd.DataFrame({"id":[1,2], "name":["A","B"]})
b = pd.DataFrame({"id":[1,2], "marks":[80,90]})

print(pd.merge(a, b, on="id"))
# Out:
#    id name  marks
# 0   1    A     80
# 1   2    B     90

# %%
df1 = pd.DataFrame({"A":[1,2]})
df2 = pd.DataFrame({"A":[3,4]})

print(pd.concat([df1, df2]))
# Out:
#    A
# 0  1
# 1  2
# 0  3
# 1  4

# %%
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
print(df.value_counts())
# Out:
#   team  score
# 0    A     10
# 1    A     20
# 2    B     30
# 3    B     40
#   team  score
# 0    A     10
# 1    A     20
# 2    B     30
# 3    B     40
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   team    4 non-null      object
#  1   score   4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes
# None
#            score
# count   4.000000
# mean   25.000000
# std    12.909944
# min    10.000000
# 25%    17.500000
# 50%    25.000000
# 75%    32.500000
# max    40.000000
# team  score
# A     10       1
#       20       1
# B     30       1
#       40       1
# Name: count, dtype: int64

# %%
df = pd.DataFrame({
    'name': ["a","b","c"],
    'age':  [10,20,30],
    'marks': [76,88,98]})

print(df[df['age']> 20])
print(df["name"] )
# Out:
#   name  age  marks
# 2    c   30     98
# 0    a
# 1    b
# 2    c
# Name: name, dtype: object

# %%
data = pd.read_csv("data.csv")
print(data.isna())
print(data.fillna(0))
print(data.dropna())
# Out:
#       Pokemon   Type  Species  Height  Weight  Abilities  EV Yield  \
# 0       False  False    False   False   False      False     False
# 1       False  False    False   False   False      False     False
# 2       False  False    False   False   False      False     False
# 3       False  False    False   False   False      False     False
# 4       False  False    False   False   False      False     False
# ...       ...    ...      ...     ...     ...        ...       ...
# 1210    False  False    False   False   False      False     False
# 1211    False  False    False   False   False      False     False
# 1212    False  False    False   False   False      False     False
# 1213    False  False    False   False   False      False     False
# 1214    False  False    False   False   False      False     False
#
#       Catch Rate  Base Friendship  Base Exp  ...  Defense Max  \
# 0          False            False     False  ...        False
# ...

# %%
df = pd.DataFrame({
    "team": ["A","A","B","B"],
    "score": [10,20,30,40]
})

print(df.groupby('team')["score"].mean())
print(df.groupby('team').agg({'score':['sum',"mean","max"]}))
# Out:
# team
# A    15.0
# B    35.0
# Name: score, dtype: float64
#      score
#        sum  mean max
# team
# A       30  15.0  20
# B       70  35.0  40

# %%
a = pd.DataFrame({"id":[1,2], "name":["A","B"]})
b = pd.DataFrame({"id":[1,2], "marks":[80,90]})

print(pd.merge(a, b, on="id"))
# Out:
#    id name  marks
# 0   1    A     80
# 1   2    B     90

# %%
print(df.sort_values("marks",ascending=False))
# Out:
#   name  age  marks
# 2    c   30     98
# 1    b   20     88
# 0    a   10     76
